# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
df1= pd.read_csv('./college.csv')
# df1= df1.drop(columns=['Type of System'])
df1['Name']= df1['State or Union Territory']+ ' '+ df1['Type of System']
df1= df1.drop(columns=['State or Union Territory','Type of System']) 
df1
# Out:
#     No. of Colleges - Govt  Admission Capacity - Govt  Permitted Seats - Govt  \
# 0                        1                        100                     100
# 1                        1                         93                      93
# 2                        2                        211                     211
# 3                        2                        216                     216
# 4                        3                        359                     359
# ..                     ...                        ...                     ...
# 76                       1                        163                     163
# 77                       9                       1027                    1027
# 78                       0                          0                       0
# 79                       5                        459                     459
# 80                       0                          0                       0
#
# ...

# %%
df1_new= pd.melt(df1, id_vars=['Name'], var_name='Type', value_name='Numbers')
sns.set_theme()
sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap='viridis', annot=True, fmt='.1f', cbar_kws={'label': 'Stocks'})
plt.title('State Wise Colleges')
plt.xlabel('Type')
plt.ylabel('Name')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 6))
sns.set_theme()
sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap='viridis', annot=True, fmt='.1f', cbar_kws={'label': 'Numbers'}, ax=axs[0])
axs[0].set_title('Poster Print')
axs[0].set_xlabel('Type')
axs[0].set_ylabel('Name')

sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap='turbo', annot=True, fmt='.1f', cbar_kws={'label': 'Numbers'}, ax=axs[1])
axs[1].set_title('Screen Display')
axs[1].set_xlabel('Type')
axs[1].set_ylabel('Name')

sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap='inferno', annot=True, fmt='.1f', cbar_kws={'label': 'Number'}, ax=axs[2])
axs[2].set_title('Presentation')
axs[2].set_xlabel('Type')
axs[2].set_ylabel('Name')
# Out:
# Text(944.217830882353, 0.5, 'Name')

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 6))
sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap='BuGn', annot=True, fmt='.1f', cbar_kws={'label': 'Numbers'}, ax=axs[0])
axs[0].set_title('Poster Print')
axs[0].set_xlabel('Type')
axs[0].set_ylabel('Name')

sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap='PuBu', annot=True, fmt='.1f', cbar_kws={'label': 'Numbers'}, ax=axs[1])
axs[1].set_title('Screen Display')
axs[1].set_xlabel('Type')
axs[1].set_ylabel('Name')

sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap='YlOrBr', annot=True, fmt='.1f', cbar_kws={'label': 'Numbers'}, ax=axs[2])
axs[2].set_title('Presentation')
axs[2].set_xlabel('Type')
axs[2].set_ylabel('Name')
# Out:
# Text(944.217830882353, 0.5, 'Name')

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 6))
sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap='coolwarm', annot=True, fmt='.1f', cbar_kws={'label': 'Numbers'}, ax=axs[0])
axs[0].set_title('Poster Print')
axs[0].set_xlabel('Type')
axs[0].set_ylabel('Name')

sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap='seismic', annot=True, fmt='.1f', cbar_kws={'label': 'Numbers'}, ax=axs[1])
axs[1].set_title('Screen Display')
axs[1].set_xlabel('Type')
axs[1].set_ylabel('Name')

sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap='RdBu', annot=True, fmt='.1f', cbar_kws={'label': 'Numbers'}, ax=axs[2])
axs[2].set_title('Presentation')
axs[2].set_xlabel('Type')
axs[2].set_ylabel('Name')
# Out:
# Text(944.217830882353, 0.5, 'Name')

# %%
from matplotlib.colors import ListedColormap
poster_cmap = ListedColormap(['#D9381E', '#009F6B', 'lightgray', 'darkgray'])
screen_cmap = ListedColormap(['blue', 'yellow', 'lightgray', 'darkgray'])
presentation_cmap = ListedColormap(['orange', '#4B0082', 'lightgray', 'darkgray'])

fig, axs = plt.subplots(1, 3, figsize=(20, 6))
sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap=poster_cmap, annot=True, fmt='.1f', cbar_kws={'label': 'Numbers'}, ax=axs[0])
axs[0].set_title('Poster Print')
axs[0].set_xlabel('Type')
axs[0].set_ylabel('Name')

sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap=screen_cmap, annot=True, fmt='.1f', cbar_kws={'label': 'Numbers'}, ax=axs[1])
axs[1].set_title('Screen Display')
axs[1].set_xlabel('Type')
axs[1].set_ylabel('Name')

sns.heatmap(df1_new.pivot('Name', 'Type', 'Numbers'), cmap=presentation_cmap, annot=True, fmt='.1f', cbar_kws={'label': 'Numbers'}, ax=axs[2])
axs[2].set_title('Presentation')
axs[2].set_xlabel('Type')
axs[2].set_ylabel('Name')
# Out:
# Text(944.217830882353, 0.5, 'Name')
